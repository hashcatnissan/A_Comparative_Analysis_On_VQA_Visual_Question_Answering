# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
data = json.load(open('/content/drive/MyDrive/Pytorch/VQA Datset/openended_zayn.json'))
print(data)
# Out:
# {'info': {'description': 'This is v2.0 of the VQA dataset.', 'url': 'http://visualqa.org', 'version': '2.0', 'year': 2017, 'contributor': 'VQA Team', 'date_created': '2017-04-26 17:00:44'}, 'task_type': 'Open-Ended', 'data_type': 'mscoco', 'license': {'url': 'http://creativecommons.org/licenses/by/4.0/', 'name': 'Creative Commons Attribution 4.0 International License'}, 'data_subtype': 'val2014', 'questions': [{'image_id': 369404, 'question': 'Is the boy wearing a tie?', 'question_id': 369404000}, {'image_id': 369404, 'question': 'What is the kid doing?', 'question_id': 369404001}, {'image_id': 369404, 'question': 'Is the child old enough to walk?', 'question_id': 369404002}, {'image_id': 369404, 'question': 'What is the boy holding?', 'question_id': 369404003}, {'image_id': 369404, 'question': 'Is the boys hair curly?', 'question_id': 369404004}, {'image_id': 369404, 'question': 'Does the boy have short hair?', 'question_id': 369404005}, {'image_id': 369404, 'question': 'Is the phot
# ...

# %%
import json

with open('/content/drive/MyDrive/Pytorch/VQA Datset/openended_zayn.json') as project_file:    
    data = json.load(project_file)  

df = pd.json_normalize(data)
print(df)
# Out:
#     task_type data_type data_subtype  \
# 0  Open-Ended    mscoco      val2014
#
#                                            questions  \
# 0  [{'image_id': 369404, 'question': 'Is the boy ...
#
#                    info.description             info.url info.version  \
# 0  This is v2.0 of the VQA dataset.  http://visualqa.org          2.0
#
#    info.year info.contributor    info.date_created  \
# 0       2017         VQA Team  2017-04-26 17:00:44
#
#                                    license.url  \
# 0  http://creativecommons.org/licenses/by/4.0/
#
#                                         license.name
# 0  Creative Commons Attribution 4.0 International...

# %%
df.head(10)
# Out:
#     task_type data_type data_subtype  \
# 0  Open-Ended    mscoco      val2014
#
#                                            questions  \
# 0  [{'image_id': 369404, 'question': 'Is the boy ...
#
#                    info.description             info.url info.version  \
# 0  This is v2.0 of the VQA dataset.  http://visualqa.org          2.0
#
#    info.year info.contributor    info.date_created  \
# 0       2017         VQA Team  2017-04-26 17:00:44
#
#                                    license.url  \
# 0  http://creativecommons.org/licenses/by/4.0/
#
#                                         license.name
# 0  Creative Commons Attribution 4.0 International...
