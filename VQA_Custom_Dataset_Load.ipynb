# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Importing JSON and Pandas Library
import json
import pandas as pd
import time
import numpy as np
question = json.load(open('/content/drive/MyDrive/VQA Custom Dataset/OpenEndedQuestion_Zayn.json'))
print(question)
# Out:
# [{'image_id': 369404, 'question': 'Is the boy wearing a tie?', 'question_id': 369404000}, {'image_id': 369404, 'question': 'What is the kid doing?', 'question_id': 369404001}, {'image_id': 369404, 'question': 'Is the child old enough to walk?', 'question_id': 369404002}, {'image_id': 369404, 'question': 'What is the boy holding?', 'question_id': 369404003}, {'image_id': 369404, 'question': 'Is the boys hair curly?', 'question_id': 369404004}, {'image_id': 369404, 'question': 'Does the boy have short hair?', 'question_id': 369404005}, {'image_id': 369404, 'question': 'Is the photo blurry?', 'question_id': 369404006}, {'image_id': 369404, 'question': 'What is the kid wearing?', 'question_id': 369404007}, {'image_id': 369404, 'question': "What color is the boy's shirt?", 'question_id': 369404008}, {'image_id': 369404, 'question': 'Was that picture taken a long time ago?', 'question_id': 369404009}, {'image_id': 369404, 'question': 'Is the boy sad?', 'question_id': 369404010}, {'image_id
# ...

# %%
for i in range(0, len(question)):
  print(question[i])
# Out:
# Streaming output truncated to the last 5000 lines.
# {'image_id': 372613, 'question': 'Are the curtains open?', 'question_id': 372613000}
# {'image_id': 372613, 'question': 'Is this a bedroom?', 'question_id': 372613001}
# {'image_id': 372613, 'question': 'Are there any mirrors on the wall?', 'question_id': 372613002}
# {'image_id': 372620, 'question': 'Is he outside?', 'question_id': 372620000}
# {'image_id': 372620, 'question': 'How many people are in the image?', 'question_id': 372620001}
# {'image_id': 372620, 'question': 'What color is his shoes?', 'question_id': 372620002}
# {'image_id': 372620, 'question': 'Is this a skate park?', 'question_id': 372620003}
# {'image_id': 372633, 'question': 'Is it cold out?', 'question_id': 372633000}
# {'image_id': 372633, 'question': 'Is this a competition?', 'question_id': 372633001}
# {'image_id': 372633, 'question': 'Has anyone else been here before?', 'question_id': 372633002}
# ...

# %%
df1 = pd.DataFrame(columns=["image_id","question","question_id"])
df1
# Out:
# Empty DataFrame
# Columns: [image_id, question, question_id]
# Index: []

# %%
for i in range(0, len(question)):
  currentItem = question[i]
  df1.loc[i] = [question[i]["image_id"],question[i]["question"],question[i]["question_id"]]

# %%
df1
# Out:
#      image_id                                     question question_id
# 0      369404                    Is the boy wearing a tie?   369404000
# 1      369404                       What is the kid doing?   369404001
# 2      369404             Is the child old enough to walk?   369404002
# 3      369404                     What is the boy holding?   369404003
# 4      369404                      Is the boys hair curly?   369404004
# ...       ...                                          ...         ...
# 6103   157559                    Are all the cows grazing?   157559009
# 6104   157559  Are there intentional designs in the field?   157559010
# 6105   157577                             How many horses?   157577000
# 6106   157577                              Is this a farm?   157577001
# 6107   157577                        Are the horses happy?   157577002
#
# [6108 rows x 3 columns]

# %%
pd.read_json("/content/drive/MyDrive/VQA Custom Dataset/OpenEndedQuestion_Zayn.json").head(20)
# Out:
#     image_id                                           question  question_id
# 0     369404                          Is the boy wearing a tie?    369404000
# 1     369404                             What is the kid doing?    369404001
# 2     369404                   Is the child old enough to walk?    369404002
# 3     369404                           What is the boy holding?    369404003
# 4     369404                            Is the boys hair curly?    369404004
# 5     369404                      Does the boy have short hair?    369404005
# 6     369404                               Is the photo blurry?    369404006
# 7     369404                           What is the kid wearing?    369404007
# 8     369404                     What color is the boy's shirt?    369404008
# 9     369404            Was that picture taken a long time ago?    369404009
# 10    369404                                    Is the boy sad?    369404010
# ...

# %%
df1.shape
# Out:
# (6108, 3)

# %%
#Importing JSON and Pandas Library
import json
import pandas as pd
annotations = json.load(open('/content/drive/MyDrive/VQA Custom Dataset/Annotations_Zayn.json'))
annotations
# Out:
# [{'answer_type': 'yes/no',
#   'answers': [{'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 1},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 2},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 3},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 4},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 5},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 6},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 7},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 8},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 9},
#    {'answer': 'no', 'answer_confidence': 'yes', 'answer_id': 10}],
#   'image_id': 369404,
#   'multiple_choice_answer': 'no',
#   'question_id': 369404000,
#   'question_type': 'is the'},
#  {'answer_type': 'other',
#   'answers': [{'answer': 'playing',
#     'answer_confidence': 'yes',
#     'answer_id': 1},
# ...

# %%
pd.read_json("/content/drive/MyDrive/VQA Custom Dataset/Annotations_Zayn.json").head(20)
# Out:
#    answer_type multiple_choice_answer  \
# 0       yes/no                     no
# 1        other                playing
# 2       yes/no                    yes
# 3        other             wii remote
# 4       yes/no                     no
# 5       yes/no                    yes
# 6       yes/no                    yes
# 7        other                  shirt
# 8        other                    red
# 9       yes/no                     no
# 10      yes/no                     no
# 11      yes/no                     no
# 12       other                  sunny
# 13      number                     10
# 14       other                   wood
# 15       other                  india
# 16      number                     13
# 17       other       talking on phone
# 18       other                  phone
# 19      yes/no                    yes
#
#                                               answers  image_id  \
# 0   [{'answer': 'no', 'answer_confidence': 'yes', ...    369404
# ...

# %% [markdown]
# Loading image data using CV2
# Importing required libraries

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras import layers, Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-61-7ad9409869f8> in <module>()
#       5 import cv2
#       6 from tensorflow import keras
# ----> 7 from tensorflow.keras import layers, Dense, Input, InputLayer, Flatten
#       8 from tensorflow.keras.models import Sequential, Model
#       9 from  matplotlib import pyplot as plt
#
# ImportError: cannot import name 'Dense' from 'tensorflow.keras' (/usr/local/lib/python3.7/dist-packages/keras/api/_v2/keras/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
